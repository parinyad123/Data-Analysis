# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline # การสร้างกราฟต้องมีสามบรรทัดนี้

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109bc5390>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109e2c198>]], dtype=object)

# %%
df.cty.hist()

# %%
df.cty.hist();

# %%
df.cty.hist(bins=20)

# %%
df[['cty', 'hwy']].hist(grid=False, color='orange', sharex=True, sharey=True);

# %%
df[['cty', 'hwy']].plot.hist()

# %%
df[['cty', 'hwy']].plot.hist(alpha=.2)

# %%
df.cty.plot.density()

# %%
df.cty.plot.kde()

# %%
df
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 0           audi                  a4    1.8  1999    4    auto(l5)   f   18
# 1           audi                  a4    1.8  1999    4  manual(m5)   f   21
# 2           audi                  a4    2.0  2008    4  manual(m6)   f   20
# 3           audi                  a4    2.0  2008    4    auto(av)   f   21
# 4           audi                  a4    2.8  1999    6    auto(l5)   f   16
# 5           audi                  a4    2.8  1999    6  manual(m5)   f   18
# 6           audi                  a4    3.1  2008    6    auto(av)   f   18
# 7           audi          a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9           audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 10          audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# ...

# %%
df['class'].value_counts()
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %%
df['class'].value_counts().plot.bar()

# %%
df['class'].value_counts().plot.barh(color='orange')

# %%
df['class'].value_counts().plot.barh(color='.7')

# %%
df['class'].value_counts().sort_values().plot.barh(color='.7') 
#เรียงให้ตัวที่มีความถี่มากสุดอยู่ด้านบน
