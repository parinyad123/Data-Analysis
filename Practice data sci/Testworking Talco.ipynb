# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
urlo = '/users/parinyaduangklang/Documents/test data sci/Data Analyst Interview data - Telco.csv'
df = pd.read_csv(urlo)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
ChY = df[df['Churn']== 'Yes'].shape
Chsum = df['Churn'].value_counts().sum()
ChYrate = ChY[0]*100/Chsum
ChYrate
# Out:
# 26.536987079369588

# %%
ChN = df[df['Churn']== 'No'].shape
ChNrate = ChN[0]*100/Chsum
ChNrate
# Out:
# 73.46301292063042

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.median()
# Out:
# SeniorCitizen      0.00
# tenure            29.00
# MonthlyCharges    70.35
# dtype: float64

# %%
ChF = df[df['gender']=='Female']['SeniorCitizen'].value_counts()
ChF
# Out:
# 0    2920
# 1     568
# Name: SeniorCitizen, dtype: int64

# %%
df[df.gender == 'Female']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 19    4183-MYFRB  Female              0      No         No      21
# 23    3638-WEABW  Female              0     Yes         No      58
# 25    6865-JZNKO  Female              0      No         No      30
# 29    8773-HHUOZ  Female              0      No        Yes      17
# 30    3841-NFECX  Female              1     Yes         No      71
# ...

# %%
df[(df.gender == 'Female') & (df.SeniorCitizen==1)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 75    2673-CXQEU  Female              1      No         No      56
# 99    4598-XLKNJ  Female              1     Yes         No      25
# 103   5386-THSLQ  Female              1     Yes         No      66
# 113   4846-WHAFZ  Female              1     Yes         No      37
# 126   4412-YLTKF  Female              1      No         No      27
# 139   0390-DCFDQ  Female              1     Yes         No       1
# 140   3146-MSEGF  Female              1     Yes        Yes      72
# 176   2656-FMOKZ  Female              1      No         No      15
# ...

# %%
df[(df.InternetService=='Fiber optic')& (df.gender == 'Female') & (df.SeniorCitizen==1)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 53    7495-OOKFY  Female              1     Yes         No       8
# 75    2673-CXQEU  Female              1      No         No      56
# 99    4598-XLKNJ  Female              1     Yes         No      25
# 113   4846-WHAFZ  Female              1     Yes         No      37
# 126   4412-YLTKF  Female              1      No         No      27
# 139   0390-DCFDQ  Female              1     Yes         No       1
# 176   2656-FMOKZ  Female              1      No         No      15
# 177   2070-FNEXE  Female              1      No         No       7
# 238   0094-OIFMO  Female              1      No         No      11
# 243   9058-HRZSV  Female              1     Yes         No      65
# 267   3197-ARFOY  Female              1      No         No      19
# ...

# %%
FFS = 424*100/568
FFS
# Out:
# 74.64788732394366

# %%
df[(df.InternetService=='DSL')& (df.gender == 'Female') & (df.SeniorCitizen==1)]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 52    6575-SUVOI  Female              1     Yes         No      25
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 103   5386-THSLQ  Female              1     Yes         No      66
# 140   3146-MSEGF  Female              1     Yes        Yes      72
# 244   4522-AKYLR  Female              1      No         No      13
# 259   5046-NUHWD  Female              1     Yes         No      29
# 320   5020-ZSTTY  Female              1      No         No      54
# 328   5697-GOMBF  Female              1     Yes        Yes      28
# 340   6035-BXTTY  Female              1      No         No      32
# 354   0623-IIHUG  Female              1      No         No      21
# 356   3351-NGXYI  Female              1      No         No      16
# 392   0224-RLWWD  Female              1      No         No       2
# 425   2055-SIFSS  Female              1     Yes         No      55
# ...

# %%
DFS = 123*100/568
DFS
# Out:
# 21.654929577464788

# %%
df[(df.InternetService=='Fiber optic')& (df.PhoneService == 'Yes')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 19    4183-MYFRB  Female              0      No         No      21
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 30    3841-NFECX  Female              1     Yes         No      71
# 31    4929-XIHVW    Male              1     Yes         No       2
# ...

# %% [markdown]
# # 5

# %%
df[df.TechSupport.isin(['No','No internet service'])]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 16    8191-XWSZG  Female              0      No         No      52
# ...

# %%
df[(df.TechSupport.isin(['No','No internet service'])) 
   & (df.PhoneService == 'Yes') & (df.MultipleLines=='Yes') &
   (df.InternetService =='Fiber optic') & (df.InternetService =='DSL') 
  & (df.OnlineSecurity=='Yes') & (df.DeviceProtection=='Yes')]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[(df.TechSupport.isin(['No','No internet service'])) 
   & (df.DeviceProtection == 'No')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 25    6865-JZNKO  Female              0      No         No      30
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 29    8773-HHUOZ  Female              0      No        Yes      17
# 34    3413-BMNZE    Male              1      No         No       1
# 36    6047-YHPVI    Male              0      No         No       5
# ...

# %% [markdown]
# # 6

# %%
import seaborn as sns
sns.boxplot(df['Churn'],df['MonthlyCharges'])

# %%
df[['Churn','MonthlyCharges']].boxplot()

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df.plot.scatter(x='tenure',y='MonthlyCharges')

# %%
df[['tenure','MonthlyCharges']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a0ddba8>,
# ...
#       dtype=object)

# %% [markdown]
# # 7

# %%
df.plot(tenure='bar',stacked=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-7dedec18a13a> in <module>()
# ----> 1 df.plot(tenure='bar',stacked=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
sns.factorplot(x='PhoneService',y='tenure', data=df,kind='violin')

# %%
sns.factorplot(x='TechSupport',y='tenure',hue='Churn', data=df,kind='violin')

# %%
sns.factorplot(x='OnlineBackup',y='tenure',hue='Churn', data=df,kind='violin')

# %%
sns.factorplot(x='OnlineSecurity',y='tenure',hue='Churn', data=df,kind='violin')

# %% [markdown]
# # 8

# %%
sns.factorplot(x='MonthlyCharges',y='TotalCharges',hue='Partner', data=df,kind='violin')

# %%
sns.factorplot(x='Partner',y='TotalCharges', data=df,kind='violin')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-8bfb0ce515b2> in <module>()
# ----> 1 sns.factorplot(x='Partner',y='TotalCharges', data=df,kind='violin')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3489     # facets to ensure representation of all data in the final plot
#    3490     p = _CategoricalPlotter()
# -> 3491     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3492     order = p.group_names
#    3493     hue_order = p.hue_names
#
# ...

# %%
import seaborn as sns
sns.set(style="ticks")
sns.factorplot(x='Partner', y='TotalCharges', hue="violin", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-4c8ffa2a9b5d> in <module>()
#       1 import seaborn as sns
#       2 sns.set(style="ticks")
# ----> 3 sns.factorplot(x='Partner', y='TotalCharges', hue="violin", data=df)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3489     # facets to ensure representation of all data in the final plot
#    3490     p = _CategoricalPlotter()
# -> 3491     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3492     order = p.group_names
#    3493     hue_order = p.hue_names
#
# ...

# %%
sns.factorplot(x='Partner',y='tenure', data=df,kind='violin')

# %%
PMT = df[['Partner','MonthlyCharges','TotalCharges']]
PMT
# Out:
#      Partner  MonthlyCharges TotalCharges
# 0        Yes           29.85        29.85
# 1         No           56.95       1889.5
# 2         No           53.85       108.15
# 3         No           42.30      1840.75
# 4         No           70.70       151.65
# 5         No           99.65        820.5
# 6         No           89.10       1949.4
# 7         No           29.75        301.9
# 8        Yes          104.80      3046.05
# 9         No           56.15      3487.95
# 10       Yes           49.95       587.45
# 11        No           18.95        326.8
# 12       Yes          100.35       5681.1
# 13        No          103.70       5036.3
# 14        No          105.50      2686.05
# 15       Yes          113.25      7895.15
# 16        No           20.65      1022.95
# 17        No          106.70      7382.25
# 18       Yes           55.20       528.35
# 19        No           90.05       1862.9
# 20        No           39.65        39.65
# ...

# %%
sns.factorplot(x='Partner',y='MonthlyCharges', data=PMT,kind='violin')

# %%
PMT.dtypes
# Out:
# Partner            object
# MonthlyCharges    float64
# TotalCharges       object
# dtype: object

# %%
PMT_T = PMT.convert_objects(convert_numeric=True)
PMT_T.dtypes
# Out:
# /Users/parinyaduangklang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# Partner            object
# MonthlyCharges    float64
# TotalCharges      float64
# dtype: object

# %%
PMT_T.dtypes
# Out:
# Partner            object
# MonthlyCharges    float64
# TotalCharges      float64
# dtype: object

# %%
sns.factorplot(x='Partner',y='TotalCharges', data=PMT_T,kind='violin')

# %%
PMT_2 = df['Partner']=='No'
ChF
# Out:
# 0    2920
# 1     568
# Name: SeniorCitizen, dtype: int64

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
#PMT_2 = df[df.Partner == 'No']
PMT_2 = df
PMT_2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
PMT_2 = PMT_2.convert_objects(convert_numeric=True)
PMT_2.dtypes
# Out:
# /Users/parinyaduangklang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# ...

# %%
PMT_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7032 non-null float64
# ...

# %%
PMT_2[PMT_2['TotalCharges'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %%
PMT_2['TotalCharges'].hist()
mean = PMT_2['TotalCharges'].mean()
mean
# Out:
# 2283.3004408418697

# %%
PMT_2['TotalCharges'].fillna(mean, inplace = True)

# %%
PMT_2[PMT_2['TotalCharges'].isnull()]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
PMT_2.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2265.000258
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1400.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
Chn_sg = PMT_2['Churn'].value_counts()
Chn_sg
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
PS_sg = PMT_2['PhoneService'].value_counts()
PS_sg
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
ML_sg = PMT_2['MultipleLines'].value_counts()
ML_sg
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
IS_sg = PMT_2['InternetService'].value_counts()
IS_sg
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
OS_sg = PMT_2['OnlineSecurity'].value_counts()
OS_sg
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
df[['tenure','MonthlyCharges']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a21f33c50>,
# ...
#       dtype=object)

# %%
OB_sg = PMT_2['OnlineBackup'].value_counts()
OB_sg
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
DP_sg = PMT_2['DeviceProtection'].value_counts()
DP_sg
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
TS_sg = PMT_2['TechSupport'].value_counts()
TS_sg
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
STV_sg = PMT_2['StreamingTV'].value_counts()
STV_sg
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64

# %%
SM_sg= PMT_2['StreamingMovies'].value_counts()
SM_sg
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %%
Ct_sg = PMT_2['Contract'].value_counts()
Ct_sg
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
PB_sg = PMT_2['PaperlessBilling'].value_counts()
PB_sg
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
PM_sg = PMT_2['PaymentMethod'].value_counts()
PM_sg
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
C_sg = PMT_2['Churn'].value_counts()
C_sg
# plt.hist(C_sg[0]);
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# # 5

# %%
df_5 = df[(df.PaperlessBilling=='Yes')& (df.TechSupport == 'Yes')]
df_5[['PaperlessBilling','TechSupport']]
# Out:
#      PaperlessBilling TechSupport
# 8                 Yes         Yes
# 14                Yes         Yes
# 23                Yes         Yes
# 28                Yes         Yes
# 30                Yes         Yes
# 43                Yes         Yes
# 44                Yes         Yes
# 48                Yes         Yes
# 49                Yes         Yes
# 52                Yes         Yes
# 54                Yes         Yes
# 57                Yes         Yes
# 59                Yes         Yes
# 63                Yes         Yes
# 65                Yes         Yes
# 72                Yes         Yes
# 74                Yes         Yes
# 83                Yes         Yes
# 92                Yes         Yes
# 96                Yes         Yes
# 104               Yes         Yes
# 114               Yes         Yes
# 119               Yes         Yes
# 125               Yes         Yes
# 140               Yes         Yes
# 145               Yes         Yes
# ...

# %% [markdown]
# # 9

# %%
df_5 = df[(df.PaperlessBilling=='Yes')& (df.Churn == 'No')]
df_5[['PaperlessBilling','Churn']]
# Out:
#      PaperlessBilling Churn
# 0                 Yes    No
# 6                 Yes    No
# 10                Yes    No
# 14                Yes    No
# 19                Yes    No
# 23                Yes    No
# 25                Yes    No
# 28                Yes    No
# 30                Yes    No
# 31                Yes    No
# 37                Yes    No
# 41                Yes    No
# 43                Yes    No
# 44                Yes    No
# 45                Yes    No
# 48                Yes    No
# 49                Yes    No
# 50                Yes    No
# 52                Yes    No
# 54                Yes    No
# 56                Yes    No
# 57                Yes    No
# 59                Yes    No
# 60                Yes    No
# 61                Yes    No
# 63                Yes    No
# 65                Yes    No
# 66                Yes    No
# 69                Yes    No
# 71                Yes    No
# ...               ...   ...
# 6981              Yes    No
# ...

# %% [markdown]
# # 10

# %%
DF_10 = df[df.Churn=='Yes']
DF_10.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
#
#    MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 2             No             DSL            Yes  ...                No
# 4             No     Fiber optic             No  ...                No
# 5            Yes     Fiber optic             No  ...               Yes
# 8            Yes     Fiber optic             No  ...               Yes
# 13           Yes     Fiber optic             No  ...               Yes
#
# ...

# %%
dpd_10 = DF_10['Dependents'].value_counts()
pe1 = dpd_10[1]

# %%
PB_10 = DF_10['PhoneService'].value_counts()
pe2 = PB_10[0]
PB_10
# Out:
# Yes    1699
# No      170
# Name: PhoneService, dtype: int64

# %%
ML_10 = DF_10['MultipleLines'].value_counts()
pe3 = ML_10[1]

# %%
IS_10 = DF_10['InternetService'].value_counts()
IS_10
# IS_10Y = IS_10[0]+IS_10[1]
pe4 = IS_10[0]

# %%
OS_10 = DF_10['OnlineSecurity'].value_counts()
pe5 = OS_10[1]

# %%
OB_10 = DF_10['OnlineBackup'].value_counts()
pe6 = OB_10[1]

# %%
DP_10 = DF_10['DeviceProtection'].value_counts()
pe7 = DP_10[1]

# %%
TS_10 = DF_10['TechSupport'].value_counts()
pe8 = TS_10[1]

# %%
STV_10 = DF_10['StreamingTV'].value_counts()
pe9 = STV_10[1]

# %%
SM_10 = DF_10['StreamingMovies'].value_counts()
pe10 = SM_10[1]
SM_10
# Out:
# No                     938
# Yes                    818
# No internet service    113
# Name: StreamingMovies, dtype: int64

# %%
Ct_10 = DF_10['Contract'].value_counts()
Ct_10
# Out:
# Month-to-month    1655
# One year           166
# Two year            48
# Name: Contract, dtype: int64

# %%
PlB_10 = DF_10['PaperlessBilling'].value_counts()
pe11  = PlB_10[0]

# %%
PMd_10 = DF_10['PaymentMethod'].value_counts()
PMd_10
# Out:
# Electronic check             1071
# Mailed check                  308
# Bank transfer (automatic)     258
# Credit card (automatic)       232
# Name: PaymentMethod, dtype: int64

# %%
import pylab as pl
import numpy as np

d = {'Deps':pe1,'PhS':pe2,'Mul':pe3,
     'InS':pe4, 'OnS':pe5, 'OnB':pe6,
    'DeP':pe7, 'TeS':pe8,'StTV':pe9,
    'StM':pe10,'Ct':Ct_10[0],'PaB':pe11,'PMd':PMd_10[0]}
X = np.arange(len(d))
pl.bar(X, d.values(), align='center', width=.5)
pl.xticks(X, d.keys())
ymax = max(d.values()) + 1
pl.ylim(0, ymax)
pl.show()

# %% [markdown]
# ##### d = {'Dependents':pe1,'PhoneService':pe2,'MultipleLines':pe3,
# #####     'InternetService':pe4, 'OnlineSecurity':pe5, 'OnlineBackup':pe6,
# #####    'DeviceProtection':pe7, 'TechSupport':pe8,'StreamingTV':pe9,
# #####    'StreamingMovies':pe10,'PaperlessBilling':pe11}

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df.pivot_table(index='Churn', columns='PhoneService', values='MultipleLines', aggfunc='count')
# Out:
# PhoneService   No   Yes
# Churn
# No            512  4662
# Yes           170  1699

# %% [markdown]
# # Bonus

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
PMT_2.shape
# Out:
# (7043, 21)

# %%
PMT_2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...   DeviceProtection  \
# 0  No phone service             DSL             No  ...                 No
# 1                No             DSL            Yes  ...                Yes
# 2                No             DSL            Yes  ...                 No
# 3  No phone service             DSL            Yes  ...                Yes
# 4                No     Fiber optic             No  ...                 No
#
# ...

# %%
DTB = PMT_2.drop(columns=['customerID'])
DTB.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
def tran_num(x):
    if x == 'Yes':
        return 1
    if x == 'No':
        return 0
    if x == 'No internet service':
        return 2

# %%
ur = '/users/parinyaduangklang/Documents/test data sci/Data Analyst Interview data - Telco1.csv'
dff = pd.read_csv(ur)
dff.head()
# Out:
#    customerID  gender  gender_num  SeniorCitizen Partner  Partner_num  \
# 0  7590-VHVEG  Female           0              0     Yes            1
# 1  5575-GNVDE    Male           1              0      No            0
# 2  3668-QPYBK    Male           1              0      No            0
# 3  7795-CFOCW    Male           1              0      No            0
# 4  9237-HQITU  Female           0              0      No            0
#
#   Dependents  Dependents_num  tenure PhoneService    ...           Contract  \
# 0         No               0       1           No    ...     Month-to-month
# 1         No               0      34          Yes    ...           One year
# 2         No               0       2          Yes    ...     Month-to-month
# 3         No               0      45           No    ...           One year
# 4         No               0       2          Yes    ...     Month-to-month
#
#   Contract_num  PaperlessBilling PaperlessBilling_num  \
# ...

# %%
print("Number of rows: ", dff.shape[0])
counts = dff.describe().iloc[0]
display(
    pd.DataFrame(
        counts.tolist(), 
        columns=["Count of values"], 
        index=counts.index.values
    ).transpose()
)
# Out:
# Number of rows:  7043
#                  gender_num  SeniorCitizen  Partner_num  Dependents_num  \
# Count of values      7043.0         7043.0       7043.0          7043.0
#
#                  tenure  PhoneService_num  MultipleLines_num  \
# Count of values  7043.0            7043.0             7043.0
#
#                  InternetService_num  OnlineSecurity_num  OnlineBackup_num  \
# Count of values               7043.0              7043.0            7043.0
#
#                  DeviceProtection_num  TechSupport_num  StreamingTV_num  \
# Count of values                7043.0           7043.0           7043.0
#
#                  StreamingMovies_num  Contract_num  PaperlessBilling_num  \
# Count of values               7043.0        7043.0                7043.0
#
#                  PaymentMethod_num  MonthlyCharges  Churn_num
# Count of values             7043.0          7043.0     7043.0

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 37 columns):
# customerID              7043 non-null object
# gender                  7043 non-null object
# gender_num              7043 non-null int64
# SeniorCitizen           7043 non-null int64
# Partner                 7043 non-null object
# Partner_num             7043 non-null int64
# Dependents              7043 non-null object
# Dependents_num          7043 non-null int64
# tenure                  7043 non-null int64
# PhoneService            7043 non-null object
# PhoneService_num        7043 non-null int64
# MultipleLines           7043 non-null object
# MultipleLines_num       7043 non-null int64
# InternetService         7043 non-null object
# InternetService_num     7043 non-null int64
# OnlineSecurity          7043 non-null object
# OnlineSecurity_num      7043 non-null int64
# OnlineBackup            7043 non-null object
# OnlineBackup_num        7043 non-null int64
# ...

# %%
dff = dff.convert_objects(convert_numeric=True)
dff.dtypes
# Out:
# /Users/parinyaduangklang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# customerID               object
# gender                   object
# gender_num                int64
# SeniorCitizen             int64
# Partner                  object
# Partner_num               int64
# Dependents               object
# Dependents_num            int64
# tenure                    int64
# PhoneService             object
# PhoneService_num          int64
# MultipleLines            object
# MultipleLines_num         int64
# InternetService          object
# InternetService_num       int64
# OnlineSecurity           object
# OnlineSecurity_num        int64
# OnlineBackup             object
# ...

# %%
# dff['TotalCharges'].fillna(mean, inplace = True)

# %%
# dff[dff['TotalCharges'].isnull()]

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 37 columns):
# customerID              7043 non-null object
# gender                  7043 non-null object
# gender_num              7043 non-null int64
# SeniorCitizen           7043 non-null int64
# Partner                 7043 non-null object
# Partner_num             7043 non-null int64
# Dependents              7043 non-null object
# Dependents_num          7043 non-null int64
# tenure                  7043 non-null int64
# PhoneService            7043 non-null object
# PhoneService_num        7043 non-null int64
# MultipleLines           7043 non-null object
# MultipleLines_num       7043 non-null int64
# InternetService         7043 non-null object
# InternetService_num     7043 non-null int64
# OnlineSecurity          7043 non-null object
# OnlineSecurity_num      7043 non-null int64
# OnlineBackup            7043 non-null object
# OnlineBackup_num        7043 non-null int64
# ...

# %%
dff=dff.dropna()  
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 37 columns):
# customerID              7032 non-null object
# gender                  7032 non-null object
# gender_num              7032 non-null int64
# SeniorCitizen           7032 non-null int64
# Partner                 7032 non-null object
# Partner_num             7032 non-null int64
# Dependents              7032 non-null object
# Dependents_num          7032 non-null int64
# tenure                  7032 non-null int64
# PhoneService            7032 non-null object
# PhoneService_num        7032 non-null int64
# MultipleLines           7032 non-null object
# MultipleLines_num       7032 non-null int64
# InternetService         7032 non-null object
# InternetService_num     7032 non-null int64
# OnlineSecurity          7032 non-null object
# OnlineSecurity_num      7032 non-null int64
# OnlineBackup            7032 non-null object
# OnlineBackup_num        7032 non-null int64
# ...

# %%
# Drop the columns that we have decided won't be used in prediction
# dff = dff.drop(["customerID", "gender", "Partner","Dependents",
#                 "PhoneService","MultipleLines","InternetService",
#                "OnlineSecurity","OnlineBackup","DeviceProtection",
#                "TechSupport","StreamingTV","StreamingMovies",
#                 "Contract","PaperlessBilling","PaymentMethod","Churn"], axis=1)
features = df.drop(["Churn_num"], axis=1).columns
dff.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-298-02fef7f701cc> in <module>()
#       5 #                "TechSupport","StreamingTV","StreamingMovies",
#       6 #                 "Contract","PaperlessBilling","PaymentMethod","Churn"], axis=1)
# ----> 7 features = df.drop(["Churn_num"], axis=1).columns
#       8 dff.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
dff_b = dff

# %%
dff_b_train, dff_b_test = train_test_split(dff_b, test_size=0.25)

# %%
# Set up our RandomForestClassifier instance and fit to data
clf = RandomForestClassifier(n_estimators=30)
clf.fit(dff_b_train[features], dff_b_train["Churn_num"])

# Make predictions
predictions = clf.predict(dff_b_test[features])
probs = clf.predict_proba(dff_b_test[features])
display(predictions)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-297-cbb8d1327a41> in <module>()
#       1 # Set up our RandomForestClassifier instance and fit to data
#       2 clf = RandomForestClassifier(n_estimators=30)
# ----> 3 clf.fit(dff_b_train[features], dff_b_train["Churn_num"])
#       4
#       5 # Make predictions
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# ...

# %%
dff['TotalCharges'].fillna(mean, inplace = True)
dff.head()
# Out:
#    customerID  gender  gender_num  SeniorCitizen Partner  Partner_num  \
# 0  7590-VHVEG  Female           0              0     Yes            1
# 1  5575-GNVDE    Male           1              0      No            0
# 2  3668-QPYBK    Male           1              0      No            0
# 3  7795-CFOCW    Male           1              0      No            0
# 4  9237-HQITU  Female           0              0      No            0
#
#   Dependents  Dependents_num  tenure PhoneService    ...           Contract  \
# 0         No               0       1           No    ...     Month-to-month
# 1         No               0      34          Yes    ...           One year
# 2         No               0       2          Yes    ...     Month-to-month
# 3         No               0      45           No    ...           One year
# 4         No               0       2          Yes    ...     Month-to-month
#
#   Contract_num  PaperlessBilling PaperlessBilling_num  \
# ...

# %%
dff[dff['TotalCharges'].isnull()]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, gender_num, SeniorCitizen, Partner, Partner_num, Dependents, Dependents_num, tenure, PhoneService, PhoneService_num, MultipleLines, MultipleLines_num, InternetService, InternetService_num, OnlineSecurity, OnlineSecurity_num, OnlineBackup, OnlineBackup_num, DeviceProtection, DeviceProtection_num, TechSupport, TechSupport_num, StreamingTV, StreamingTV_num, StreamingMovies, StreamingMovies_num, Contract, Contract_num, PaperlessBilling, PaperlessBilling_num, PaymentMethod, PaymentMethod_num, MonthlyCharges, TotalCharges, Churn, Churn_num]
# Index: []
#
# [0 rows x 37 columns]

# %%
print("Number of rows: ", dff.shape[0])
counts = dff.describe().iloc[0]
display(
    pd.DataFrame(
        counts.tolist(), 
        columns=["TotalCharges"], 
        index=counts.index.values
    ).transpose()
)
# Out:
# Number of rows:  7043
#               gender_num  SeniorCitizen  Partner_num  Dependents_num  tenure  \
# TotalCharges      7043.0         7043.0       7043.0          7043.0  7043.0
#
#               PhoneService_num  MultipleLines_num  InternetService_num  \
# TotalCharges            7043.0             7043.0               7043.0
#
#               OnlineSecurity_num  OnlineBackup_num  DeviceProtection_num  \
# TotalCharges              7043.0            7043.0                7043.0
#
#               TechSupport_num  StreamingTV_num  StreamingMovies_num  \
# TotalCharges           7043.0           7043.0               7043.0
#
#               Contract_num  PaperlessBilling_num  PaymentMethod_num  \
# TotalCharges        7043.0                7043.0             7043.0
#
#               MonthlyCharges  TotalCharges  Churn_num
# TotalCharges          7043.0        7043.0     7043.0
